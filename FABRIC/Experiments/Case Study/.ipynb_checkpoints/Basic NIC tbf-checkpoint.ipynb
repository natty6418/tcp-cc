# %% [markdown]
# ## Replication: When to use and when not to use BBR: An empirical analysis and evaluation study
#
# This experiment replicates Figure 5 of
#
# > Yi Cao, Arpit Jain, Kriti Sharma, Aruna Balasubramanian, and Anshul Gandhi. 2019. When to use and when not to use BBR: An empirical analysis and evaluation study. In Proceedings of the Internet Measurement Conference (IMC ’19). Association for Computing Machinery, New York, NY, USA, 130–136. https://doi.org/10.1145/3355369.3355579
#
# and also extends it to a more recent version of BBRv1 and to BBRv2.

# %% [markdown]
# To run this experiment:
#
# -   **Prerequisites**: You should have a FABRIC account, be part of a FABRIC project, and have configured your FABRIC Jupyter environment, as in [“Hello, FABRIC”](https://teaching-on-testbeds.github.io/blog/hello-fabric). Then, `git clone` this repository in the FABRIC JupyterHub environment, navigate to the “fabric-notebooks” directory, and open the “fabric-run.ipynb” file.
# -   **Configuration**: Next, you need to edit some parts of this notebook, depending on the version of the experiment you want to run.
#     -   In the “Define configuration for this experiment” section, set the `slice_name` prefix - slice names must be unique, so if you are running multiple slices in parallel (for example, to validate the result for the three BBR versions in parallel slices), make each have a unique name.
#     -   In the “Define configuration for this experiment” section, set the `image` variable - “default_ubuntu_18” to validate the result in the original paper (4.15 kernel), “default_ubuntu_22” for a newer BBRv1 (5.15 kernel), or “default_ubuntu_20” for BBRv2 (will use 5.13 kernel).
#     -   If you are evaluating BBRv2, in the “Extra configuration for this experiment” section set `is_bbr2` to `True`. (Otherwise, leave it as `False`.)
#     -   If you are evaluating BBRv2, in the “Execute experiment” section set the `cc` in the `exp_factors` dictionary to `["cubic", "bbr2"]`. (Otherwise, leave it at `["cubic", "bbr"]`.)
#     -   If you are running multiple versions of this notebook in parallel, it’s easiest to duplicate the notebook (right-click on the file in the JupyterHub file browser, choose Duplicate), configure the copy as described above, and execute the copy.
# -   **Execution**: Once you are ready, you’ll want to run all of the cells in this notebook in order. An easy way to do this is to scroll to the “Delete your slice” section at the end, click on the cell that has the title of this section, and choose Run \> Run All Above Selected Cell from the JupyterHub menu to run all cells until this point.
#     -   In case there is a problem reserving resources (i.e. an infrastructure problem), you will want to delete your slice and try again. To do this, you would run the cells in the “Delete your slice” section, make sure your slice is deleted, then run the cells above that section again (using Run \> Run All Above Selected Cell for convenience).
#     -   This full-factorial experiment design takes many hours to run. Once you have confirmed that the main loop in the “Execute experiment” section is running, you can leave this notebook running unattended.
#     -   Every 24 hours or less, your FABRIC JupyterHub session will time out, and you’ll need to resume execution. When you get the alert that your server has stopped, you should: (1) Force restart your JupyterHub server: File \> Hub Control Panel \> Stop My Server, then Start Server. (2) Re-run the first few code cells, until you see the output “You already have a slice by this name!”. (3) Scroll to the “Execute experiment” section and continue running cells in order from this point on.

# %% [markdown]
# ### Configure environment

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
fablib = fablib_manager() 
conf = fablib.show_config()
# Out:
# <style type="text/css">
# #T_dc3e7 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_dc3e7 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_dc3e7 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_dc3e7_row0_col0, #T_dc3e7_row0_col1, #T_dc3e7_row1_col0, #T_dc3e7_row1_col1, #T_dc3e7_row2_col0, #T_dc3e7_row2_col1, #T_dc3e7_row3_col0, #T_dc3e7_row3_col1, #T_dc3e7_row4_col0, #T_dc3e7_row4_col1, #T_dc3e7_row5_col0, #T_dc3e7_row5_col1, #T_dc3e7_row6_col0, #T_dc3e7_row6_col1, #T_dc3e7_row7_col0, #T_dc3e7_row7_col1, #T_dc3e7_row8_col0, #T_dc3e7_row8_col1, #T_dc3e7_row9_col0, #T_dc3e7_row9_col1, #T_dc3e7_row10_col0, #T_dc3e7_row10_col1, #T_dc3e7_row11_col0, #T_dc3e7_row11_col1, #T_dc3e7_row12_col0, #T_dc3e7_row12_col1, #T_dc3e7_row13_col0, #T_dc3e7_row13_col1, #T_dc3e7_row14_col0, #T_dc3e7_row14_col1, #T_dc3e7_row15_col0, #T_dc3e7_row15_col1, #T_dc3e7_row16_col0, #T_dc3e7_row16_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_dc3e7">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dc3e7_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_dc3e7_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_dc3e7_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row2_col0" class="data row2 col0" >Project ID</td>
#       <td id="T_dc3e7_row2_col1" class="data row2 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_dc3e7_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row4_col0" class="data row4 col0" >Bastion Host</td>
#       <td id="T_dc3e7_row4_col1" class="data row4 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row5_col0" class="data row5 col0" >Bastion Username</td>
#       <td id="T_dc3e7_row5_col1" class="data row5 col1" >nm3833_0000195331</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row6_col0" class="data row6 col0" >Bastion Private Key File</td>
#       <td id="T_dc3e7_row6_col1" class="data row6 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row7_col0" class="data row7 col0" >Slice Private Key File</td>
#       <td id="T_dc3e7_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_dc3e7_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row9_col0" class="data row9 col0" >Log File</td>
#       <td id="T_dc3e7_row9_col1" class="data row9 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row10_col0" class="data row10 col0" >Log Level</td>
#       <td id="T_dc3e7_row10_col1" class="data row10 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_dc3e7_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_dc3e7_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_dc3e7_row13_col1" class="data row13 col1" >1.7.2</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row14_col0" class="data row14 col0" >Data directory</td>
#       <td id="T_dc3e7_row14_col1" class="data row14 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row15_col0" class="data row15 col0" >Core API</td>
#       <td id="T_dc3e7_row15_col1" class="data row15 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_dc3e7_row16_col0" class="data row16 col0" >Bastion SSH Config File</td>
#       <td id="T_dc3e7_row16_col1" class="data row16 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Define configuration for this experiment

# %%
slice_name="re-when-to-use-bbr-tbf" + fablib.get_bastion_username()

# use default_ubuntu_22 for 5.15 kernel, default_ubuntu_18 for 4.15 kernel, default_ubuntu_20 for BBRv2
image = 'default_ubuntu_22' 

node_conf = [
 {'name': "h1",  'cores': 4, 'ram': 16, 'disk': 500, 'image': image, 'packages': ['iperf3']}, 
 {'name': "h2",  'cores': 4, 'ram': 16, 'disk': 10, 'image': image, 'packages': ['iperf3']}, 
 {'name': "h3",  'cores': 4, 'ram': 16, 'disk': 10, 'image': image, 'packages': ['iperf3']}, 
 {'name': "tbf", 'cores': 8, 'ram': 32, 'disk': 10, 'image': image, 'packages': []} 
]
net_conf = [
 {"name": "link1", "subnet": "10.10.1.0/24", "nodes": [{"name": "tbf",   "addr": "10.10.1.10"}, {"name": "h1", "addr": "10.10.1.1"}]},
 {"name": "link2", "subnet": "10.10.2.0/24", "nodes": [{"name": "tbf",   "addr": "10.10.2.10"}, {"name": "h2", "addr": "10.10.2.1"}]},
 {"name": "link3", "subnet": "10.10.3.0/24", "nodes": [{"name": "tbf",   "addr": "10.10.3.10"}, {"name": "h3", "addr": "10.10.3.1"}]}
]
route_conf = [
 {"addr": "10.10.3.0/24", "gw": "10.10.1.10", "nodes": ["h1"]}, 
 {"addr": "10.10.3.0/24", "gw": "10.10.2.10", "nodes": ["h2"]},  
 {"addr": "10.10.1.0/24", "gw": "10.10.3.10", "nodes": ["h3"]},  
 {"addr": "10.10.2.0/24", "gw": "10.10.3.10", "nodes": ["h3"]}
]
exp_conf = {'cores': sum([ n['cores'] for n in node_conf]), 'nic': sum([len(n['nodes']) for n in net_conf]) }

# %% [markdown]
# ### Reserve resources
#
# Now, we are ready to reserve resources!

# %% [markdown]
# First, make sure you don’t already have a slice with this name:

# %%
try:
    slice = fablib.get_slice(slice_name)
    print("You already have a slice by this name!")
    print("If you previously reserved resources, skip to the 'log in to resources' section.")
except:
    print("You don't have a slice named %s yet." % slice_name)
    print("Continue to the next step to make one.")
    slice = fablib.new_slice(name=slice_name)
# Out:
# You already have a slice by this name!
# If you previously reserved resources, skip to the 'log in to resources' section.

# %% [markdown]
# We will select a random site that has sufficient resources for our experiment:

# %%
# while True:
#     site_name = fablib.get_random_site()
#     if ( (fablib.resources.get_core_available(site_name) > 1.2*exp_conf['cores']) and
#         (fablib.resources.get_component_available(site_name, 'SharedNIC-ConnectX-6') > 1.2**exp_conf['nic']) ):
#         break
site_name = 'EDUKY'
fablib.show_site(site_name)
# Out:
# <style type="text/css">
# #T_cd502 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_cd502 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_cd502 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_cd502_row0_col0, #T_cd502_row0_col1, #T_cd502_row1_col0, #T_cd502_row1_col1, #T_cd502_row2_col0, #T_cd502_row2_col1, #T_cd502_row3_col0, #T_cd502_row3_col1, #T_cd502_row4_col0, #T_cd502_row4_col1, #T_cd502_row5_col0, #T_cd502_row5_col1, #T_cd502_row6_col0, #T_cd502_row6_col1, #T_cd502_row7_col0, #T_cd502_row7_col1, #T_cd502_row8_col0, #T_cd502_row8_col1, #T_cd502_row9_col0, #T_cd502_row9_col1, #T_cd502_row10_col0, #T_cd502_row10_col1, #T_cd502_row11_col0, #T_cd502_row11_col1, #T_cd502_row12_col0, #T_cd502_row12_col1, #T_cd502_row13_col0, #T_cd502_row13_col1, #T_cd502_row14_col0, #T_cd502_row14_col1, #T_cd502_row15_col0, #T_cd502_row15_col1, #T_cd502_row16_col0, #T_cd502_row16_col1, #T_cd502_row17_col0, #T_cd502_row17_col1, #T_cd502_row18_col0, #T_cd502_row18_col1, #T_cd502_row19_col0, #T_cd502_row19_col1, #T_cd502_row20_col0, #T_cd502_row20_col1, #T_cd502_row21_col0, #T_cd502_row21_col1, #T_cd502_row22_col0, #T_cd502_row22_col1, #T_cd502_row23_col0, #T_cd502_row23_col1, #T_cd502_row24_col0, #T_cd502_row24_col1, #T_cd502_row25_col0, #T_cd502_row25_col1, #T_cd502_row26_col0, #T_cd502_row26_col1, #T_cd502_row27_col0, #T_cd502_row27_col1, #T_cd502_row28_col0, #T_cd502_row28_col1, #T_cd502_row29_col0, #T_cd502_row29_col1, #T_cd502_row30_col0, #T_cd502_row30_col1, #T_cd502_row31_col0, #T_cd502_row31_col1, #T_cd502_row32_col0, #T_cd502_row32_col1, #T_cd502_row33_col0, #T_cd502_row33_col1, #T_cd502_row34_col0, #T_cd502_row34_col1, #T_cd502_row35_col0, #T_cd502_row35_col1, #T_cd502_row36_col0, #T_cd502_row36_col1, #T_cd502_row37_col0, #T_cd502_row37_col1, #T_cd502_row38_col0, #T_cd502_row38_col1, #T_cd502_row39_col0, #T_cd502_row39_col1, #T_cd502_row40_col0, #T_cd502_row40_col1, #T_cd502_row41_col0, #T_cd502_row41_col1, #T_cd502_row42_col0, #T_cd502_row42_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_cd502">
#   <caption>Site</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cd502_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_cd502_row0_col1" class="data row0 col1" >EDUKY</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row1_col0" class="data row1 col0" >State</td>
#       <td id="T_cd502_row1_col1" class="data row1 col1" >Active</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row2_col0" class="data row2 col0" >Address</td>
#       <td id="T_cd502_row2_col1" class="data row2 col1" >301 Hilltop Avenue,Lexington, KY 40506</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row3_col0" class="data row3 col0" >Location</td>
#       <td id="T_cd502_row3_col1" class="data row3 col1" >(0, 0)</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row4_col0" class="data row4 col0" >PTP Capable</td>
#       <td id="T_cd502_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row5_col0" class="data row5 col0" >Hosts</td>
#       <td id="T_cd502_row5_col1" class="data row5 col1" >18</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row6_col0" class="data row6 col0" >CPUs</td>
#       <td id="T_cd502_row6_col1" class="data row6 col1" >36</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row7_col0" class="data row7 col0" >Cores Available</td>
#       <td id="T_cd502_row7_col1" class="data row7 col1" >73656</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row8_col0" class="data row8 col0" >Cores Capacity</td>
#       <td id="T_cd502_row8_col1" class="data row8 col1" >73728</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row9_col0" class="data row9 col0" >Cores Allocated</td>
#       <td id="T_cd502_row9_col1" class="data row9 col1" >72</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row10_col0" class="data row10 col0" >RAM Available</td>
#       <td id="T_cd502_row10_col1" class="data row10 col1" >8316</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row11_col0" class="data row11 col0" >RAM Capacity</td>
#       <td id="T_cd502_row11_col1" class="data row11 col1" >8604</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row12_col0" class="data row12 col0" >RAM Allocated</td>
#       <td id="T_cd502_row12_col1" class="data row12 col1" >288</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row13_col0" class="data row13 col0" >Disk Available</td>
#       <td id="T_cd502_row13_col1" class="data row13 col1" >130572</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row14_col0" class="data row14 col0" >Disk Capacity</td>
#       <td id="T_cd502_row14_col1" class="data row14 col1" >134082</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row15_col0" class="data row15 col0" >Disk Allocated</td>
#       <td id="T_cd502_row15_col1" class="data row15 col1" >3510</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row16_col0" class="data row16 col0" >Basic NIC Available</td>
#       <td id="T_cd502_row16_col1" class="data row16 col1" >4409</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row17_col0" class="data row17 col0" >Basic NIC Capacity</td>
#       <td id="T_cd502_row17_col1" class="data row17 col1" >4445</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row18_col0" class="data row18 col0" >Basic NIC Allocated</td>
#       <td id="T_cd502_row18_col1" class="data row18 col1" >36</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row19_col0" class="data row19 col0" >ConnectX-6 Available</td>
#       <td id="T_cd502_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row20_col0" class="data row20 col0" >ConnectX-6 Capacity</td>
#       <td id="T_cd502_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row21_col0" class="data row21 col0" >ConnectX-6 Allocated</td>
#       <td id="T_cd502_row21_col1" class="data row21 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row22_col0" class="data row22 col0" >ConnectX-5 Available</td>
#       <td id="T_cd502_row22_col1" class="data row22 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row23_col0" class="data row23 col0" >ConnectX-5 Capacity</td>
#       <td id="T_cd502_row23_col1" class="data row23 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row24_col0" class="data row24 col0" >ConnectX-5 Allocated</td>
#       <td id="T_cd502_row24_col1" class="data row24 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row25_col0" class="data row25 col0" >NVMe Available</td>
#       <td id="T_cd502_row25_col1" class="data row25 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row26_col0" class="data row26 col0" >NVMe Capacity</td>
#       <td id="T_cd502_row26_col1" class="data row26 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row27_col0" class="data row27 col0" >NVMe Allocated</td>
#       <td id="T_cd502_row27_col1" class="data row27 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row28_col0" class="data row28 col0" >Tesla T4 Available</td>
#       <td id="T_cd502_row28_col1" class="data row28 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row29_col0" class="data row29 col0" >Tesla T4 Capacity</td>
#       <td id="T_cd502_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row30_col0" class="data row30 col0" >Tesla T4 Allocated</td>
#       <td id="T_cd502_row30_col1" class="data row30 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row31_col0" class="data row31 col0" >RTX6000 Available</td>
#       <td id="T_cd502_row31_col1" class="data row31 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row32_col0" class="data row32 col0" >RTX6000 Capacity</td>
#       <td id="T_cd502_row32_col1" class="data row32 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row33_col0" class="data row33 col0" >RTX6000 Allocated</td>
#       <td id="T_cd502_row33_col1" class="data row33 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cd502_row34_col0" class="data row34 col0" >A30 Available</td>
#       <td id="T_cd502_row34_col1" class="data row34 col1" >0</td>
#     </tr>
#     <tr>
# '<pandas.io.formats.style.Styler object at 0x7c2257ed1890>'

# %% [markdown]
# Then we will add hosts and network segments:

# %%
# this cell sets up the nodes
for n in node_conf:
    slice.add_node(name=n['name'], site=site_name, 
                   cores=n['cores'], 
                   ram=n['ram'], 
                   disk=n['disk'], 
                   image=n['image'])

# %%
# this cell sets up the network segments
for n in net_conf:
    ifaces = [slice.get_node(node["name"]).add_component(model="NIC_Basic", 
                                                 name=n["name"]).get_interfaces()[0] for node in n['nodes'] ]
    slice.add_l2network(name=n["name"], type='L2Bridge', interfaces=ifaces)

# %% [markdown]
# The following cell submits our request to the FABRIC site. The output of this cell will update automatically as the status of our request changes.
#
# -   While it is being prepared, the “State” of the slice will appear as “Configuring”.
# -   When it is ready, the “State” of the slice will change to “StableOK”.
#
# You may prefer to walk away and come back in a few minutes (for simple slices) or a few tens of minutes (for more complicated slices with many resources).

# %%
slice.submit()
# Out:
# Retry: 12, Time: 410 sec
# <style type="text/css">
# #T_d2226 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_d2226 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d2226 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_d2226_row0_col0, #T_d2226_row0_col1, #T_d2226_row1_col0, #T_d2226_row1_col1, #T_d2226_row2_col0, #T_d2226_row2_col1, #T_d2226_row3_col0, #T_d2226_row3_col1, #T_d2226_row4_col0, #T_d2226_row4_col1, #T_d2226_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_d2226_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_d2226">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d2226_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_d2226_row0_col1" class="data row0 col1" >a4827ebc-9858-43e3-b192-65be44d8ba7e</td>
#     </tr>
#     <tr>
#       <td id="T_d2226_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_d2226_row1_col1" class="data row1 col1" >re-when-to-use-bbr-tbfnm3833_0000195331</td>
#     </tr>
#     <tr>
#       <td id="T_d2226_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_d2226_row2_col1" class="data row2 col1" >2024-07-15 00:53:03 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_d2226_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_d2226_row3_col1" class="data row3 col1" >2024-07-14 00:53:04 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_d2226_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_d2226_row4_col1" class="data row4 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_d2226_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_d2226_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0eb01 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0eb01 th {
#   text-align: left;
# }
# #T_0eb01 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0eb01 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0eb01 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0eb01_row0_col0, #T_0eb01_row0_col1, #T_0eb01_row0_col2, #T_0eb01_row0_col3, #T_0eb01_row0_col4, #T_0eb01_row0_col5, #T_0eb01_row0_col6, #T_0eb01_row0_col7, #T_0eb01_row0_col8, #T_0eb01_row0_col9, #T_0eb01_row0_col10, #T_0eb01_row0_col13, #T_0eb01_row0_col14, #T_0eb01_row0_col15, #T_0eb01_row1_col0, #T_0eb01_row1_col1, #T_0eb01_row1_col2, #T_0eb01_row1_col3, #T_0eb01_row1_col4, #T_0eb01_row1_col5, #T_0eb01_row1_col6, #T_0eb01_row1_col7, #T_0eb01_row1_col8, #T_0eb01_row1_col9, #T_0eb01_row1_col10, #T_0eb01_row1_col13, #T_0eb01_row1_col14, #T_0eb01_row1_col15, #T_0eb01_row2_col0, #T_0eb01_row2_col1, #T_0eb01_row2_col2, #T_0eb01_row2_col3, #T_0eb01_row2_col4, #T_0eb01_row2_col5, #T_0eb01_row2_col6, #T_0eb01_row2_col7, #T_0eb01_row2_col8, #T_0eb01_row2_col9, #T_0eb01_row2_col10, #T_0eb01_row2_col13, #T_0eb01_row2_col14, #T_0eb01_row2_col15, #T_0eb01_row3_col0, #T_0eb01_row3_col1, #T_0eb01_row3_col2, #T_0eb01_row3_col3, #T_0eb01_row3_col4, #T_0eb01_row3_col5, #T_0eb01_row3_col6, #T_0eb01_row3_col7, #T_0eb01_row3_col8, #T_0eb01_row3_col9, #T_0eb01_row3_col10, #T_0eb01_row3_col13, #T_0eb01_row3_col14, #T_0eb01_row3_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_0eb01_row0_col11, #T_0eb01_row1_col11, #T_0eb01_row2_col11, #T_0eb01_row3_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_0eb01_row0_col12, #T_0eb01_row1_col12, #T_0eb01_row2_col12, #T_0eb01_row3_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_0eb01">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_0eb01_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_0eb01_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_0eb01_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_0eb01_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_0eb01_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_0eb01_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_0eb01_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_0eb01_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_0eb01_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_0eb01_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_0eb01_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_0eb01_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_0eb01_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_0eb01_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_0eb01_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_0eb01_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0eb01_row0_col0" class="data row0 col0" >4ad0acc7-5f5e-489c-b096-9d8d7d3cbcd2</td>
#       <td id="T_0eb01_row0_col1" class="data row0 col1" >h1</td>
#       <td id="T_0eb01_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_0eb01_row0_col3" class="data row0 col3" >16</td>
#       <td id="T_0eb01_row0_col4" class="data row0 col4" >500</td>
#       <td id="T_0eb01_row0_col5" class="data row0 col5" >default_ubuntu_22</td>
#       <td id="T_0eb01_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_0eb01_row0_col7" class="data row0 col7" >eduky-w15.fabric-testbed.net</td>
#       <td id="T_0eb01_row0_col8" class="data row0 col8" >EDUKY</td>
#       <td id="T_0eb01_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_0eb01_row0_col10" class="data row0 col10" >2610:1e0:1700:206:f816:3eff:fe3e:1ce8</td>
#       <td id="T_0eb01_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_0eb01_row0_col12" class="data row0 col12" ></td>
#       <td id="T_0eb01_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe3e:1ce8</td>
#       <td id="T_0eb01_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_0eb01_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0eb01_row1_col0" class="data row1 col0" >c94338cd-a4db-4006-87d1-1abe8c365ae0</td>
#       <td id="T_0eb01_row1_col1" class="data row1 col1" >h2</td>
#       <td id="T_0eb01_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_0eb01_row1_col3" class="data row1 col3" >16</td>
#       <td id="T_0eb01_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_0eb01_row1_col5" class="data row1 col5" >default_ubuntu_22</td>
#       <td id="T_0eb01_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_0eb01_row1_col7" class="data row1 col7" >eduky-w6.fabric-testbed.net</td>
#       <td id="T_0eb01_row1_col8" class="data row1 col8" >EDUKY</td>
#       <td id="T_0eb01_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_0eb01_row1_col10" class="data row1 col10" >2610:1e0:1700:206:f816:3eff:fe98:bbb0</td>
#       <td id="T_0eb01_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_0eb01_row1_col12" class="data row1 col12" ></td>
#       <td id="T_0eb01_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe98:bbb0</td>
#       <td id="T_0eb01_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_0eb01_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0eb01_row2_col0" class="data row2 col0" >6b2d7ffd-d880-4033-a1d3-971f91d34537</td>
#       <td id="T_0eb01_row2_col1" class="data row2 col1" >h3</td>
#       <td id="T_0eb01_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_0eb01_row2_col3" class="data row2 col3" >16</td>
#       <td id="T_0eb01_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_0eb01_row2_col5" class="data row2 col5" >default_ubuntu_22</td>
#       <td id="T_0eb01_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_0eb01_row2_col7" class="data row2 col7" >eduky-w11.fabric-testbed.net</td>
#       <td id="T_0eb01_row2_col8" class="data row2 col8" >EDUKY</td>
#       <td id="T_0eb01_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_0eb01_row2_col10" class="data row2 col10" >2610:1e0:1700:206:f816:3eff:fee8:7e8</td>
#       <td id="T_0eb01_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_0eb01_row2_col12" class="data row2 col12" ></td>
#       <td id="T_0eb01_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fee8:7e8</td>
#       <td id="T_0eb01_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_0eb01_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0eb01_row3_col0" class="data row3 col0" >a58b03ad-bae2-4248-8281-fc1605445b19</td>
#       <td id="T_0eb01_row3_col1" class="data row3 col1" >tbf</td>
#       <td id="T_0eb01_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_0eb01_row3_col3" class="data row3 col3" >32</td>
#       <td id="T_0eb01_row3_col4" class="data row3
# <style type="text/css">
# #T_a7453 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_a7453 th {
#   text-align: left;
# }
# #T_a7453 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a7453 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_a7453 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a7453_row0_col0, #T_a7453_row0_col1, #T_a7453_row0_col2, #T_a7453_row0_col3, #T_a7453_row0_col4, #T_a7453_row0_col5, #T_a7453_row0_col6, #T_a7453_row1_col0, #T_a7453_row1_col1, #T_a7453_row1_col2, #T_a7453_row1_col3, #T_a7453_row1_col4, #T_a7453_row1_col5, #T_a7453_row1_col6, #T_a7453_row2_col0, #T_a7453_row2_col1, #T_a7453_row2_col2, #T_a7453_row2_col3, #T_a7453_row2_col4, #T_a7453_row2_col5, #T_a7453_row2_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_a7453_row0_col7, #T_a7453_row1_col7, #T_a7453_row2_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_a7453_row0_col8, #T_a7453_row1_col8, #T_a7453_row2_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_a7453">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_a7453_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_a7453_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_a7453_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_a7453_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_a7453_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_a7453_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_a7453_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_a7453_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_a7453_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a7453_row0_col0" class="data row0 col0" >a2ceae63-6c53-429f-8365-28f1b23e211a</td>
#       <td id="T_a7453_row0_col1" class="data row0 col1" >link1</td>
#       <td id="T_a7453_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_a7453_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_a7453_row0_col4" class="data row0 col4" >EDUKY</td>
#       <td id="T_a7453_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_a7453_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_a7453_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_a7453_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_a7453_row1_col0" class="data row1 col0" >73e6efbc-7ac7-47ae-82b1-54e7d25c7fd8</td>
#       <td id="T_a7453_row1_col1" class="data row1 col1" >link2</td>
#       <td id="T_a7453_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_a7453_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_a7453_row1_col4" class="data row1 col4" >EDUKY</td>
#       <td id="T_a7453_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_a7453_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_a7453_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_a7453_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_a7453_row2_col0" class="data row2 col0" >3fe77bdf-f9ae-41eb-848c-ea02c521643d</td>
#       <td id="T_a7453_row2_col1" class="data row2 col1" >link3</td>
#       <td id="T_a7453_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_a7453_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_a7453_row2_col4" class="data row2 col4" >EDUKY</td>
#       <td id="T_a7453_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_a7453_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_a7453_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_a7453_row2_col8" class="data row2 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e4519 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e4519 th {
#   text-align: left;
# }
# #T_e4519 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e4519 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e4519 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e4519_row0_col0, #T_e4519_row0_col1, #T_e4519_row0_col2, #T_e4519_row0_col3, #T_e4519_row0_col4, #T_e4519_row0_col5, #T_e4519_row0_col6, #T_e4519_row0_col7, #T_e4519_row0_col8, #T_e4519_row0_col9, #T_e4519_row0_col10, #T_e4519_row0_col11, #T_e4519_row1_col0, #T_e4519_row1_col1, #T_e4519_row1_col2, #T_e4519_row1_col3, #T_e4519_row1_col4, #T_e4519_row1_col5, #T_e4519_row1_col6, #T_e4519_row1_col7, #T_e4519_row1_col8, #T_e4519_row1_col9, #T_e4519_row1_col10, #T_e4519_row1_col11, #T_e4519_row2_col0, #T_e4519_row2_col1, #T_e4519_row2_col2, #T_e4519_row2_col3, #T_e4519_row2_col4, #T_e4519_row2_col5, #T_e4519_row2_col6, #T_e4519_row2_col7, #T_e4519_row2_col8, #T_e4519_row2_col9, #T_e4519_row2_col10, #T_e4519_row2_col11, #T_e4519_row3_col0, #T_e4519_row3_col1, #T_e4519_row3_col2, #T_e4519_row3_col3, #T_e4519_row3_col4, #T_e4519_row3_col5, #T_e4519_row3_col6, #T_e4519_row3_col7, #T_e4519_row3_col8, #T_e4519_row3_col9, #T_e4519_row3_col10, #T_e4519_row3_col11, #T_e4519_row4_col0, #T_e4519_row4_col1, #T_e4519_row4_col2, #T_e4519_row4_col3, #T_e4519_row4_col4, #T_e4519_row4_col5, #T_e4519_row4_col6, #T_e4519_row4_col7, #T_e4519_row4_col8, #T_e4519_row4_col9, #T_e4519_row4_col10, #T_e4519_row4_col11, #T_e4519_row5_col0, #T_e4519_row5_col1, #T_e4519_row5_col2, #T_e4519_row5_col3, #T_e4519_row5_col4, #T_e4519_row5_col5, #T_e4519_row5_col6, #T_e4519_row5_col7, #T_e4519_row5_col8, #T_e4519_row5_col9, #T_e4519_row5_col10, #T_e4519_row5_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_e4519">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_e4519_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_e4519_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_e4519_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_e4519_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_e4519_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_e4519_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_e4519_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_e4519_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_e4519_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_e4519_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_e4519_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_e4519_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e4519_row0_col0" class="data row0 col0" >h1-link1-p1</td>
#       <td id="T_e4519_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_e4519_row0_col2" class="data row0 col2" >h1</td>
#       <td id="T_e4519_row0_col3" class="data row0 col3" >link1</td>
#       <td id="T_e4519_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_e4519_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_e4519_row0_col6" class="data row0 col6" ></td>
#       <td id="T_e4519_row0_col7" class="data row0 col7" >0E:C0:1D:30:AA:72</td>
#       <td id="T_e4519_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_e4519_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_e4519_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_e4519_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e4519_row1_col0" class="data row1 col0" >h2-link2-p1</td>
#       <td id="T_e4519_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_e4519_row1_col2" class="data row1 col2" >h2</td>
#       <td id="T_e4519_row1_col3" class="data row1 col3" >link2</td>
#       <td id="T_e4519_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_e4519_row1_col5" class="data row1 col5" >config</td>
#       <td id="T_e4519_row1_col6" class="data row1 col6" ></td>
#       <td id="T_e4519_row1_col7" class="data row1 col7" >0A:3A:54:55:BC:67</td>
#       <td id="T_e4519_row1_col8" class="data row1 col8" >enp7s0</td>
#       <td id="T_e4519_row1_col9" class="data row1 col9" >enp7s0</td>
#       <td id="T_e4519_row1_col10" class="data row1 col10" >None</td>
#       <td id="T_e4519_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e4519_row2_col0" class="data row2 col0" >h3-link3-p1</td>
#       <td id="T_e4519_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_e4519_row2_col2" class="data row2 col2" >h3</td>
#       <td id="T_e4519_row2_col3" class="data row2 col3" >link3</td>
#       <td id="T_e4519_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_e4519_row2_col5" class="data row2 col5" >config</td>
#       <td id="T_e4519_row2_col6" class="data row2 col6" ></td>
#       <td id="T_e4519_row2_col7" class="data row2 col7" >02:3A:AD:D9:CD:20</td>
#       <td id="T_e4519_row2_col8" class="data row2 col8" >enp7s0</td>
#       <td id="T_e4519_row2_col9" class="data row2 col9" >enp7s0</td>
#       <td id="T_e4519_row2_col10" class="data row2 col10" >None</td>
#       <td id="T_e4519_row2_col11" class="data row2 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e4519_row3_col0" class="data row3 col0" >tbf-link1-p1</td>
#       <td id="T_e4519_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_e4519_row3_col2" class="data row3 col2" >tbf</td>
#       <td id="T_e4519_row3_col3" class="data row3 col3" >link1</td>
#       <td id="T_e4519_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_e4519_row3_col5" class="data row3 col5" >config</td>
#       <td id="T_e4519_row3_col6" class="data row3 col6" ></td>
#       <td id="T_e4519_row3_col7" class="data row3 col7" >02:9F:ED:0B:B8:06</td>
#       <td id="T_e4519_row3_col8" class="data row3 col8" >enp7s0</td>
#       <td id="T_e4519_row3_col9" class="data row3 col9" >enp7s0</td>
#       <td id="T_e4519_row3_col10" class="data row3 col10" >None</td>
#       <td id="T_e4519_row3_col11" class="data row3 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e4519_row4_col0" class="data row4 col0" >tbf-link2-p1</td>
#       <td id="T_e4519_row4_col1" class="data row4 col1" >p1</td>
#       <td id="T_e4519_row4_col2" class="data row4 col2" >tbf</td>
#       <td id="T_e4519_row4_col3" class="data row4 col3" >link2</td>
#       <td id="T_e4519_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_e4519_row4_col5" class="data row4 col5" >config</td>
#       <td id="T_e4519_row4_col6" class="data row4 col6" ></td>
#       <td id="T_e4519_row4_col7" class="data row4 col7" >12:88:11:38:60:C3</td>
#       <td id="T_e4519_row4_col8" class="data row4 col8" >enp9s0</td>
#       <td id="T_e4519_row4_col9" class="data row4 col9" >enp9s0</td>
#       <td id="T_e4519_row4_col10" class="data row4 col10" >None</td>
#       <td id="T_e4519_row4_col11" class="data row4 col11" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e4519_row5_col0" class="data row5 col0" >tbf-link3-p1</td>
#       <td id="T_e4519_row5_col1" class="data row5 col1" >p1</td>
#       <td id="T_e4519_row5_col2" class="data row5 col2" >tbf</td>
#       <td id="T_e4519_row5_col3" class="data row5 col3" >link3</td>
#       <td id="T_e4519_row5_col4" class="data row5 col4" >100</td>
#       <td id="T_e4519_row5_col5" class="data row5 col5" >config</td>
#       <td id="T_e4519_row5_col6" class="data row5 col6" ></td>
#       <td id="T_e4519_row5_col7" class="data row5 col7" >12:71:B4:38:5C:82</td>
#       <td id="T_e4519_row5_col8" class="data row5 col8" >enp8s0</td>
#       <td id="T_e4519_row5_col9" class="data row5 col9" >enp8s0</td>
#       <td id="T_e4519_row5_col10" class="data row5 col10" >None</td>
# Time to print interfaces 416 seconds
# 'a4827ebc-9858-43e3-b192-65be44d8ba7e'

# %%
slice.get_state()
slice.wait_ssh(progress=True)
# Out:
# Waiting for slice . Slice state: StableOK
# Waiting for ssh in slice . ssh successful
# True

# %% [markdown]
# ### Extend slice for one week

# %%
from datetime import datetime
from datetime import timezone
from datetime import timedelta

# Set end date to 7 days from now
end_date = (datetime.now(timezone.utc) + timedelta(days=7)).strftime("%Y-%m-%d %H:%M:%S %z")
slice.renew(end_date)

# %%
slice.update()
_ = slice.show()
# Out:
# <style type="text/css">
# #T_5acbb tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5acbb tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5acbb caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_5acbb_row0_col0, #T_5acbb_row0_col1, #T_5acbb_row1_col0, #T_5acbb_row1_col1, #T_5acbb_row2_col0, #T_5acbb_row2_col1, #T_5acbb_row3_col0, #T_5acbb_row3_col1, #T_5acbb_row4_col0, #T_5acbb_row4_col1, #T_5acbb_row5_col0, #T_5acbb_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5acbb">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5acbb_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_5acbb_row0_col1" class="data row0 col1" >a4827ebc-9858-43e3-b192-65be44d8ba7e</td>
#     </tr>
#     <tr>
#       <td id="T_5acbb_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_5acbb_row1_col1" class="data row1 col1" >re-when-to-use-bbr-tbfnm3833_0000195331</td>
#     </tr>
#     <tr>
#       <td id="T_5acbb_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_5acbb_row2_col1" class="data row2 col1" >2024-07-21 01:00:06 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_5acbb_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_5acbb_row3_col1" class="data row3 col1" >2024-07-14 00:53:04 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_5acbb_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_5acbb_row4_col1" class="data row4 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_5acbb_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_5acbb_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Extra configuration for this experiment

# %%
# if you need to install BBR2 kernel, make this True
is_bbr2 = False
pkg_list = ['linux-headers-5.13.12_5.13.12-2_amd64.deb',
            'linux-libc-dev_5.13.12-2_amd64.deb',
            'linux-image-5.13.12_5.13.12-2_amd64.deb']
if is_bbr2:
    for node in slice.get_nodes():
        for pkg in pkg_list:
            node.upload_file("../setup/" + pkg, "/home/ubuntu/" + pkg)
        node.execute("sudo dpkg -i " + " ".join(pkg_list) + "; sudo reboot")

        # if compiling from scratch.... which takes forever...
        # node.execute("sudo apt update; sudo apt -y install libelf-dev libssl-dev libncurses-dev flex bison pkg-config gcc binutils ca-certificates build-essential")
        # node.execute("git clone -o google-bbr -b v2alpha  https://github.com/google/bbr.git")
        # node.upload_file("../setup/.config", "/home/ubuntu/bbr/.config")
        # node.execute("cd bbr; sudo make -j $(nproc) ")
        # node.execute("cd bbr; sudo make modules -j $(nproc) ")
        # node.execute("cd bbr; sudo make modules_install -j $(nproc) ")
        # node.execute("cd bbr; sudo make install -j $(nproc) ")

    # wait for all nodes to come back up
    slice.wait_ssh(progress=True)
    for node in slice.get_nodes():
        node.execute("hostname; uname -a")

# %%
# set socket read and write buffer on all endpoints to larger value
for node in slice.get_nodes():
    node.execute("sudo sysctl -w net.core.rmem_default=2147483647")
    node.execute("sudo sysctl -w net.core.wmem_default=2147483647")
    node.execute("sudo sysctl -w net.core.rmem_max=2147483647")
    node.execute("sudo sysctl -w net.core.wmem_max=2147483647")
# Out:
# net.core.rmem_default = 2147483647
# net.core.wmem_default = 2147483647
# net.core.rmem_max = 2147483647
# net.core.wmem_max = 2147483647
# net.core.rmem_default = 2147483647
# net.core.wmem_default = 2147483647
# net.core.rmem_max = 2147483647
# net.core.wmem_max = 2147483647
# net.core.rmem_default = 2147483647
# net.core.wmem_default = 2147483647
# net.core.rmem_max = 2147483647
# net.core.wmem_max = 2147483647
# net.core.rmem_default = 2147483647
# net.core.wmem_default = 2147483647
# net.core.rmem_max = 2147483647
# net.core.wmem_max = 2147483647

# %% [markdown]
# ### Configure resources
#
# Next, we will configure the resources so they are ready to use.

# %%
slice = fablib.get_slice(name=slice_name)

# %%
# install packages
# this will take a while and will run in background while you do other steps
for n in node_conf:
    if len(n['packages']):
        node = slice.get_node(n['name'])
        pkg = " ".join(n['packages'])
        node.execute_thread("sudo apt update; sudo apt -y install %s" % pkg)

# %%
#turn off segmentation offload on interfaces
for iface in slice.get_interfaces():
    iface_name = iface.get_device_name()
    n = iface.get_node()
    offloads = ['gro', 'lro', 'gso', 'tso']
    for offload in offloads:
        n.execute("sudo ethtool -K %s %s off" % (iface_name, offload))

# %%
# bring interfaces up and either assign an address (if there is one) or flush address
from ipaddress import ip_address, IPv4Address, IPv4Network

for net in net_conf:
    for n in net['nodes']:
        if_name = n['name'] + '-' + net['name'] + '-p1'
        iface = slice.get_interface(if_name)
        iface.ip_link_up()
        if n['addr']:
            iface.ip_addr_add(addr=n['addr'], subnet=IPv4Network(net['subnet']))
        else:
            iface.get_node().execute("sudo ip addr flush dev %s"  % iface.get_device_name())

# %%
# prepare a "hosts" file that has names and addresses of every node
hosts_txt = [ "%s\t%s" % ( n['addr'], n['name'] ) for net in net_conf  for n in net['nodes'] if type(n) is dict and n['addr']]
for n in slice.get_nodes():
    for h in hosts_txt:
        n.execute("echo %s | sudo tee -a /etc/hosts" % h)
# Out:
# 10.10.1.10 tbf
# 10.10.1.1 h1
# 10.10.2.10 tbf
# 10.10.2.1 h2
# 10.10.3.10 tbf
# 10.10.3.1 h3
# 10.10.1.10 tbf
# 10.10.1.1 h1
# 10.10.2.10 tbf
# 10.10.2.1 h2
# 10.10.3.10 tbf
# 10.10.3.1 h3
# 10.10.1.10 tbf
# 10.10.1.1 h1
# 10.10.2.10 tbf
# 10.10.2.1 h2
# 10.10.3.10 tbf
# 10.10.3.1 h3
# 10.10.1.10 tbf
# 10.10.1.1 h1
# 10.10.2.10 tbf
# 10.10.2.1 h2
# 10.10.3.10 tbf
# 10.10.3.1 h3

# %%
# enable IPv4 forwarding on all nodes
for n in slice.get_nodes():
    n.execute("sudo sysctl -w net.ipv4.ip_forward=1")
# Out:
# net.ipv4.ip_forward = 1
# net.ipv4.ip_forward = 1
# net.ipv4.ip_forward = 1
# net.ipv4.ip_forward = 1

# %%
# set up static routes
for rt in route_conf:
    for n in rt['nodes']:
        slice.get_node(name=n).ip_route_add(subnet=IPv4Network(rt['addr']), gateway=rt['gw'])

# %% [markdown]
# ### Validate base network
#
# Before we run any experiment, we should check the “base” network - before adding any emulated delay or rate limiting - and make sure that it will not be a limiting factor in the experiment.

# %%
# check base delay
slice.get_node("h1").execute("ping -c 5 h3")
# Out:
# PING h3 (10.10.3.1) 56(84) bytes of data.
# 64 bytes from h3 (10.10.3.1): icmp_seq=1 ttl=63 time=0.982 ms
# 64 bytes from h3 (10.10.3.1): icmp_seq=2 ttl=63 time=0.190 ms
# 64 bytes from h3 (10.10.3.1): icmp_seq=3 ttl=63 time=0.180 ms
# 64 bytes from h3 (10.10.3.1): icmp_seq=4 ttl=63 time=0.154 ms
# 64 bytes from h3 (10.10.3.1): icmp_seq=5 ttl=63 time=0.166 ms
#
# --- h3 ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4065ms
# rtt min/avg/max/mdev = 0.154/0.334/0.982/0.324 ms
# ('PING h3 (10.10.3.1) 56(84) bytes of data.\n64 bytes from h3 (10.10.3.1): icmp_seq=1 ttl=63 time=0.982 ms\n64 bytes from h3 (10.10.3.1): icmp_seq=2 ttl=63 time=0.190 ms\n64 bytes from h3 (10.10.3.1): icmp_seq=3 ttl=63 time=0.180 ms\n64 bytes from h3 (10.10.3.1): icmp_seq=4 ttl=63 time=0.154 ms\n64 bytes from h3 (10.10.3.1): icmp_seq=5 ttl=63 time=0.166 ms\n\n--- h3 ping statistics ---\n5 packets transmitted, 5 received, 0% packet loss, time 4065ms\nrtt min/avg/max/mdev = 0.154/0.334/0.982/0.324 ms\n',
#  '')

# %%
# check base capacity (by sending 10 parallel flows, look at their sum throughput)
import time
slice.get_node("h3").execute("iperf3 -s -1 -D")
time.sleep(5)
slice.get_node("h1").execute("iperf3 -t 30 -i 10 -P 10 -c h3")
# Out:
# Connecting to host h3, port 5201
# [  5] local 10.10.1.1 port 53006 connected to 10.10.3.1 port 5201
# [  7] local 10.10.1.1 port 53014 connected to 10.10.3.1 port 5201
# [  9] local 10.10.1.1 port 53024 connected to 10.10.3.1 port 5201
# [ 11] local 10.10.1.1 port 53026 connected to 10.10.3.1 port 5201
# [ 13] local 10.10.1.1 port 53036 connected to 10.10.3.1 port 5201
# [ 15] local 10.10.1.1 port 53046 connected to 10.10.3.1 port 5201
# [ 17] local 10.10.1.1 port 53060 connected to 10.10.3.1 port 5201
# [ 19] local 10.10.1.1 port 53066 connected to 10.10.3.1 port 5201
# [ 21] local 10.10.1.1 port 53082 connected to 10.10.3.1 port 5201
# [ 23] local 10.10.1.1 port 53086 connected to 10.10.3.1 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-10.00  sec  1.24 GBytes  1.07 Gbits/sec  678    376 KBytes
# [  7]   0.00-10.00  sec  1.31 GBytes  1.13 Gbits/sec  417    399 KBytes
# [  9]   0.00-10.00  sec  1.31 GBytes  1.12 Gbits/sec  407    451 KBytes
# [ 11]   0.00-10.00  sec  1.29 GBytes  1.11 Gbits/sec  718    479 KBytes
# [ 13]   0.00-10.00  sec  1.27 GBytes  1.09 Gbits/sec  417    590 KBytes
# [ 15]   0.00-10.00  sec  1.28 GBytes  1.10 Gbits/sec  371    444 KBytes
# [ 17]   0.00-10.00  sec  1.28 GBytes  1.10 Gbits/sec  471    417 KBytes
# [ 19]   0.00-10.00  sec  1.22 GBytes  1.05 Gbits/sec  522    486 KBytes
# [ 21]   0.00-10.00  sec  1.25 GBytes  1.07 Gbits/sec  1053    445 KBytes
# [ 23]   0.00-10.00  sec  1.28 GBytes  1.10 Gbits/sec  562    448 KBytes
# [SUM]   0.00-10.00  sec  12.7 GBytes  10.9 Gbits/sec  5616
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [  5]  10.00-20.00  sec   838 MBytes   703 Mbits/sec  213    290 KBytes
# [  7]  10.00-20.00  sec   929 MBytes   779 Mbits/sec   43    407 KBytes
# [  9]  10.00-20.00  sec  1001 MBytes   840 Mbits/sec    0    451 KBytes
# [ 11]  10.00-20.00  sec   851 MBytes   714 Mbits/sec   95    320 KBytes
# [ 13]  10.00-20.00  sec  1001 MBytes   840 Mbits/sec    0    655 KBytes
# [ 15]  10.00-20.00  sec   989 MBytes   829 Mbits/sec   53    387 KBytes
# [ 17]  10.00-20.00  sec  1000 MBytes   839 Mbits/sec    0    417 KBytes
# [ 19]  10.00-20.00  sec   991 MBytes   832 Mbits/sec   79    431 KBytes
# [ 21]  10.00-20.00  sec   855 MBytes   717 Mbits/sec  256    370 KBytes
# [ 23]  10.00-20.00  sec   850 MBytes   713 Mbits/sec   48    488 KBytes
# [SUM]  10.00-20.00  sec  9.09 GBytes  7.81 Gbits/sec  787
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [  5]  20.00-30.00  sec   862 MBytes   723 Mbits/sec   55    351 KBytes
# [  7]  20.00-30.00  sec   885 MBytes   742 Mbits/sec  103    315 KBytes
# [  9]  20.00-30.00  sec  1.08 GBytes   930 Mbits/sec    0    451 KBytes
# [ 11]  20.00-30.00  sec   870 MBytes   730 Mbits/sec   98    399 KBytes
# [ 13]  20.00-30.00  sec  1.08 GBytes   930 Mbits/sec    0    660 KBytes
# [ 15]  20.00-30.00  sec  1.03 GBytes   885 Mbits/sec   25    578 KBytes
# [ 17]  20.00-30.00  sec  1.08 GBytes   930 Mbits/sec    0    420 KBytes
# [ 19]  20.00-30.00  sec  1.09 GBytes   932 Mbits/sec   51    506 KBytes
# [ 21]  20.00-30.00  sec   889 MBytes   746 Mbits/sec  180    335 KBytes
# [ 23]  20.00-30.00  sec  1.03 GBytes   887 Mbits/sec   54    580 KBytes
# [SUM]  20.00-30.00  sec  9.82 GBytes  8.44 Gbits/sec  566
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-30.00  sec  2.90 GBytes   831 Mbits/sec  946             sender
# [  5]   0.00-30.04  sec  2.89 GBytes   827 Mbits/sec                  receiver
# [  7]   0.00-30.00  sec  3.08 GBytes   883 Mbits/sec  563             sender
# [  7]   0.00-30.04  sec  3.08 GBytes   880 Mbits/sec                  receiver
# [  9]   0.00-30.00  sec  3.37 GBytes   964 Mbits/sec  407             sender
# [  9]   0.00-30.04  sec  3.36 GBytes   961 Mbits/sec                  receiver
# [ 11]   0.00-30.00  sec  2.97 GBytes   852 Mbits/sec  911             sender
# [ 11]   0.00-30.04  sec  2.97 GBytes   849 Mbits/sec                  receiver
# [ 13]   0.00-30.00  sec  3.33 GBytes   953 Mbits/sec  417             sender
# [ 13]   0.00-30.04  sec  3.32 GBytes   949 Mbits/sec                  receiver
# [ 15]   0.00-30.00  sec  3.28 GBytes   938 Mbits/sec  449             sender
# [ 15]   0.00-30.04  sec  3.27 GBytes   935 Mbits/sec                  receiver
# [ 17]   0.00-30.00  sec  3.34 GBytes   956 Mbits/sec  471             sender
# [ 17]   0.00-30.04  sec  3.33 GBytes   953 Mbits/sec                  receiver
# [ 19]   0.00-30.00  sec  3.27 GBytes   937 Mbits/sec  652             sender
# [ 19]   0.00-30.04  sec  3.26 GBytes   933 Mbits/sec                  receiver
# [ 21]   0.00-30.00  sec  2.95 GBytes   846 Mbits/sec  1489             sender
# [ 21]   0.00-30.04  sec  2.95 GBytes   843 Mbits/sec                  receiver
# [ 23]   0.00-30.00  sec  3.14 GBytes   900 Mbits/sec  664             sender
# [ 23]   0.00-30.04  sec  3.14 GBytes   897 Mbits/sec                  receiver
# [SUM]   0.00-30.00  sec  31.6 GBytes  9.06 Gbits/sec  6969             sender
# [SUM]   0.00-30.04  sec  31.6 GBytes  9.03 Gbits/sec                  receiver
#
# iperf Done.
# ('Connecting to host h3, port 5201\n[  5] local 10.10.1.1 port 53006 connected to 10.10.3.1 port 5201\n[  7] local 10.10.1.1 port 53014 connected to 10.10.3.1 port 5201\n[  9] local 10.10.1.1 port 53024 connected to 10.10.3.1 port 5201\n[ 11] local 10.10.1.1 port 53026 connected to 10.10.3.1 port 5201\n[ 13] local 10.10.1.1 port 53036 connected to 10.10.3.1 port 5201\n[ 15] local 10.10.1.1 port 53046 connected to 10.10.3.1 port 5201\n[ 17] local 10.10.1.1 port 53060 connected to 10.10.3.1 port 5201\n[ 19] local 10.10.1.1 port 53066 connected to 10.10.3.1 port 5201\n[ 21] local 10.10.1.1 port 53082 connected to 10.10.3.1 port 5201\n[ 23] local 10.10.1.1 port 53086 connected to 10.10.3.1 port 5201\n[ ID] Interval           Transfer     Bitrate         Retr  Cwnd\n[  5]   0.00-10.00  sec  1.24 GBytes  1.07 Gbits/sec  678    376 KBytes       \n[  7]   0.00-10.00  sec  1.31 GBytes  1.13 Gbits/sec  417    399 KBytes       \n[  9]   0.00-10.00  sec  1.31 GBytes  1.12 Gbits/sec  407    451 KBytes       \n[ 11]   0.00-10.00  sec  1.29 GBytes  1.11 Gbits/sec  718    479 KBytes       \n[ 13]   0.00-10.00  sec  1.27 GBytes  1.09 Gbits/sec  417    590 KBytes       \n[ 15]   0.00-10.00  sec  1.28 GBytes  1.10 Gbits/sec  371    444 KBytes       \n[ 17]   0.00-10.00  sec  1.28 GBytes  1.10 Gbits/sec  471    417 KBytes       \n[ 19]   0.00-10.00  sec  1.22 GBytes  1.05 Gbits/sec  522    486 KBytes       \n[ 21]   0.00-10.00  sec  1.25 GBytes  1.07 Gbits/sec  1053    445 KBytes       \n[ 23]   0.00-10.00  sec  1.28 GBytes  1.10 Gbits/sec  562    448 KBytes       \n[SUM]   0.00-10.00  sec  12.7 GBytes  10.9 Gbits/sec  5616             \n- - - - - - - - - - - - - - - - - - - - - - - - -\n[  5]  10.00-20.00  sec   838 MBytes   703 Mbits/sec  213    290 KBytes       \n[  7]  10.00-20.00  sec   929 MBytes   779 Mbits/sec   43    407 KBytes       \n[  9]  10.00-20.00  sec  1001 MBytes   840 Mbits/sec    0    451 KBytes       \n[ 11]  10.00-20.00  sec   851 MBytes   714 Mbits/sec   95    320 KBytes       \n[ 13]  10.00-20.00  sec  1001 MBytes   840 Mbits/sec    0    655 KBytes       \n[ 15]  10.00-20.00  sec   989 MBytes   829 Mbits/sec   53    387 KBytes       \n[ 17]  10.00-20.00  sec  1000 MBytes   839 Mbits/sec    0    417 KBytes       \n[ 19]  10.00-20.00  sec   991 MBytes   832 Mbits/sec   79    431 KBytes       \n[ 21]  10.00-20.00  sec   855 MBytes   717 Mbits/sec  256    370 KBytes       \n[ 23]  10.00-20.00  sec   850 MBytes   713 Mbits/sec   48    488 KBytes       \n[SUM]  10.00-20.00  sec  9.09 GBytes  7.81 Gbits/sec  787             \n- - - - - - - - - - - - - - - - - - - - - - - - -\n[  5]  20.00-30.00  sec   862 MBytes   723 Mbits/sec   55    351 KBytes       \n[  7]  20.00-30.00  sec   885 MBytes   742 Mbits/sec  103    315 KBytes       \n[  9]  20.00-30.00  sec  1.08 GBytes   930 Mbits/sec    0    451 KBytes       \n[ 11]  20.00-30.00  sec   870 MBytes   730 Mbits/sec   98    399 KBytes       \n[ 13]  20.00-30.00  sec  1.08 GBytes   930 Mbits/sec    0    660 KBytes       \n[ 15]  20.00-30.00  sec  1.03 GBytes   885 Mbits/sec   25    578 KBytes       \n[ 17]  20.00-30.00  sec  1.08 GBytes   930 Mbits/sec    0    420 KBytes       \n[ 19]  20.00-30.00  sec  1.09 GBytes   932 Mbits/sec   51    506 KBytes       \n[ 21]  20.00-30.00  sec   889 MBytes   746 Mbits/sec  180    335 KBytes       \n[ 23]  20.00-30.00  sec  1.03 GBytes   887 Mbits/sec   54    580 KBytes       \n[SUM]  20.00-30.00  sec  9.82 GBytes  8.44 Gbits/sec  566             \n- - - - - - - - - - - - - - - - - - - - - - - - -\n[ ID] Interval           Transfer     Bitrate         Retr\n[  5]   0.00-30.00  sec  2.90 GBytes   831 Mbits/sec  946             sender\n[  5]   0.00-30.04  sec  2.89 GBytes   827 Mbits/sec                  receiver\n[  7]   0.00-30.00  sec  3.08 GBytes   883 Mbits/sec  563             sender\n[  7]   0.00-30.04  sec  3.08 GBytes   880 Mbits/sec                  receiver\n[  9]   0.00-30.00  sec  3.37 GBytes   964 Mbits/sec  407             sender\n[   ...
#  '')

# %%
# also check Linux kernel version on sender
slice.get_node("h1").execute("uname -a")
# Out:
# Linux h1 5.15.0-91-generic #101-Ubuntu SMP Tue Nov 14 13:30:08 UTC 2023 x86_64 x86_64 x86_64 GNU/Linux
# ('Linux h1 5.15.0-91-generic #101-Ubuntu SMP Tue Nov 14 13:30:08 UTC 2023 x86_64 x86_64 x86_64 GNU/Linux\n',
#  '')

# %% [markdown]
# ### Draw the network topology

# %% [markdown]
# The following cell will draw the network topology, for your reference. The interface name and addresses of each experiment interface will be shown on the drawing.

# %%
l2_nets = [(n.get_name(), {'color': 'lavender'}) for n in slice.get_l2networks() ]
l3_nets = [(n.get_name(), {'color': 'pink'}) for n in slice.get_l3networks() ]
hosts   =   [(n.get_name(), {'color': 'lightblue'}) for n in slice.get_nodes()]
nodes = l2_nets + l3_nets + hosts
ifaces = [iface.toDict() for iface in slice.get_interfaces()]
edges = [(iface['network'], iface['node'], 
          {'label': iface['physical_dev'] + '\n' + iface['ip_addr'] + '\n' + iface['mac']}) for iface in ifaces]

# %%
import networkx as nx
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 10))
G = nx.Graph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)
pos = nx.spring_layout(G, k=1)  # Adjust the 'k' value to space out the nodes

nx.draw(G, pos, node_shape='s',  
        node_color=[n[1]['color'] for n in nodes], 
        node_size=[len(n[0])*400 for n in nodes],  
        with_labels=True)

nx.draw_networkx_edge_labels(G, pos,
                             edge_labels=nx.get_edge_attributes(G, 'label'),
                             font_color='gray', font_size=8, rotate=False)

plt.show()

# %% [markdown]
# ### Log into resources

# %% [markdown]
# Now, we are finally ready to log in to our resources over SSH! Run the following cells, and observe the table output - you will see an SSH command for each of the resources in your topology.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
slice_info = [{'Name': n.get_name(), 'SSH command': n.get_ssh_command()} for n in slice.get_nodes()]
pd.DataFrame(slice_info).set_index('Name')
# Out:
#                                                                                                                                       SSH command
# Name
# h1    ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe3e:1ce8
# h2    ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe98:bbb0
# h3     ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fee8:7e8
# tbf   ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe3e:6bbc

# %% [markdown]
# Now, you can open an SSH session on any of the resources as follows:
#
# -   in Jupyter, from the menu bar, use File \> New \> Terminal to open a new terminal.
# -   copy an SSH command from the table, and paste it into the terminal. (Note that each SSH command is a single line, even if the display wraps the text to a second line! When you copy and paste it, paste it all together.)
#
# You can repeat this process (open several terminals) to start a session on each resource. Each terminal session will have a tab in the Jupyter environment, so that you can easily switch between them.

# %% [markdown]
# ### Execute experiment

# %%
# generate full factorial experiment
import itertools
exp_factors = { 
    'bufcap': [100, 10000],
    'bandwidth': [10, 20, 50, 100, 250, 500, 750, 1000],
    'rtt': [5, 10, 25, 50, 75, 100, 150, 200],
    'cc': ["cubic", "bbr"],
    'trial': [1,2,3,4,5]
}
factor_names = [k for k in exp_factors]
factor_lists = list(itertools.product(*exp_factors.values()))
exp_lists = [dict(zip(factor_names, factor_l)) for factor_l in factor_lists]

# %%
# get name of router interface that is 'toward' h1 - apply delay here
# get name of router interface that is 'toward' h3 - apply rate limiting and buffer size limit here
router_node = slice.get_node(name='tbf')
router_ingress_iface = router_node.get_interface(network_name = "link1")
router_ingress_name = router_ingress_iface.get_device_name()
router_egress_iface  = router_node.get_interface(network_name = "link3")
router_egress_name = router_egress_iface.get_device_name()

# %%
tx_node = slice.get_node(name="h1")
rx_node = slice.get_node(name="h3")

# %%
kernel = tx_node.execute("uname -r")[0].strip()
data_dir = kernel + "_" + exp_factors['cc'][0] + "_" + exp_factors['cc'][1]
# tx_node.execute("rm -rf "+data_dir)
# tx_node.execute("mkdir -p " + data_dir)
# Out:
# 5.15.0-91-generic

# %%
import time # to allow resume
for exp in exp_lists:

    # check if we already ran this experiment
    # (allow stop/resume)
    file_out = data_dir + "/%d_%d_%d_%d_%s.txt" % (exp['bufcap'], exp['bandwidth'], exp['rtt'], exp['trial'], exp['cc'])
    stdout, stderr = tx_node.execute("ls " + file_out, quiet=True)

    if len(stdout):
        print("Already have " + file_out + ", skipping")

    elif len(stderr):
        print("Running experiment to generate " + file_out)

        tx_node.execute("sudo modprobe tcp_" + exp['cc'])
        rx_node.execute("sudo modprobe tcp_" + exp['cc']) # iperf3 on ubuntu 18.04 requires this if using BBR and setting window size..

        router_node.execute("sudo tc qdisc del dev " + router_ingress_name + " root")
        router_node.execute("sudo tc qdisc del dev " + router_egress_name + " root")

        # set up RTT
        router_node.execute("sudo tc qdisc add dev " + router_ingress_name + " root netem delay " + str(exp['rtt']) + "ms limit 10000")
        # set up rate limit, buffer limit
        # router_node.execute("sudo tc qdisc replace dev " + router_egress_name + " root handle 1: htb default 3")
        router_node.execute("sudo tc qdisc add dev " + router_egress_name + " root handle 1: tbf rate " + str(exp['bandwidth']) + "Mbit burst 1m limit 10000")
        router_node.execute("sudo tc qdisc add dev " + router_egress_name + " parent 1: handle 2: bfifo limit " + str(exp['bufcap']) + "kb")

        time.sleep(10)
        rx_node.execute("iperf3 -s -1 -D")
        tx_node.execute("iperf3 -V -c h3 -C " + exp['cc'] + " -t 60s -fk -w 100M --logfile " + file_out, quiet=True)
# Out:
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_5_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_5_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_5_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_5_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_5_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_5_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_10_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_10_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_10_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_10_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_10_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_10_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_25_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_25_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_25_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_25_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_25_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_25_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_50_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_50_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_50_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_50_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_50_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_50_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_75_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_75_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_75_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_75_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_75_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_75_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_100_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_100_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_100_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_100_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_100_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_100_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_150_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_150_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_150_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_150_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_150_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_150_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_200_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_200_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_200_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_200_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_200_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_10_200_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_5_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_5_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_5_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_5_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_5_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_5_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_10_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_10_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_10_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_10_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_10_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_10_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_25_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_25_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_25_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_25_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_25_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_25_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_50_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_50_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_50_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_50_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_50_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_50_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_75_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_75_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_75_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_75_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_75_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_75_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_100_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_100_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_100_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_100_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_100_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_100_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_150_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_150_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_150_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_150_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_150_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_150_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_200_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_200_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_200_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_200_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_200_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_20_200_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_5_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_5_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_5_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_5_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_5_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_5_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_10_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_10_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_10_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_10_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_10_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_10_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_25_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_25_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_25_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_25_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_25_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_25_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_50_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_50_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_50_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_50_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_50_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_50_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_75_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_75_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_75_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_75_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_75_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_75_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_100_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_100_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_100_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_100_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_100_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_100_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_150_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_150_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_150_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_150_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_150_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_150_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_200_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_200_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_200_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_200_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_200_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_50_200_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_5_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_5_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_5_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_5_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_5_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_5_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_10_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_10_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_10_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_10_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_10_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_10_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_25_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_25_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_25_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_25_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_25_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_25_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_50_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_50_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_50_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_50_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_50_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_50_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_75_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_75_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_75_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_75_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_75_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_75_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_100_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_100_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_100_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_100_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_100_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_100_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_150_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_150_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_150_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_150_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_150_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_150_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_200_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_200_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_200_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_200_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_200_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_100_200_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_5_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_5_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_5_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_5_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_5_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_5_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_10_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_10_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_10_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_10_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_10_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_10_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_25_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_25_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_25_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_25_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_25_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_25_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_50_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_50_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_50_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_50_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_50_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_50_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_75_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_75_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_75_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_75_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_75_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_75_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_100_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_100_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_100_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_100_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_100_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_100_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_150_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_150_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_150_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_150_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_150_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_150_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_200_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_200_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_200_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_200_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_200_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_250_200_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_5_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_5_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_5_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_5_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_5_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_5_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_10_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_10_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_10_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_10_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_10_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_10_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_25_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_25_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_25_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_25_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_25_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_25_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_50_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_50_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_50_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_50_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_50_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_50_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_75_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_75_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_75_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_75_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_75_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_75_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_100_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_100_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_100_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_100_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_100_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_100_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_150_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_150_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_150_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_150_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_150_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_150_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_200_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_200_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_200_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_200_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_200_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_500_200_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_5_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_5_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_5_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_5_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_5_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_5_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_10_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_10_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_10_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_10_1_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_10_2_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_10_3_bbr.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_25_1_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_25_2_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_25_3_cubic.txt, skipping
# Already have 5.15.0-91-generic_cubic_bbr/10000_750_25_1_bbr.txt, skipping
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_25_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_25_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_50_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_50_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_50_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_50_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_50_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_50_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_75_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_75_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_75_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_75_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_75_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_75_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_100_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_100_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_100_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_100_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_100_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_100_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_150_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_150_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_150_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_150_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_150_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_150_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_200_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_200_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_200_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_200_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_200_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_750_200_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_5_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_5_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_5_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_5_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_5_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_5_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_10_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_10_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_10_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_10_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_10_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_10_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_25_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_25_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_25_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_25_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_25_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_25_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_50_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_50_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_50_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_50_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_50_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_50_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_75_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_75_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_75_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_75_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_75_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_75_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_100_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_100_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_100_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_100_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_100_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_100_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_150_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_150_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_150_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_150_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_150_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_150_3_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_200_1_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_200_2_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_200_3_cubic.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_200_1_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_200_2_bbr.txt
# Running experiment to generate 5.15.0-91-generic_cubic_bbr/10000_1000_200_3_bbr.txt

# %% [markdown]
# ### Analyze experiment results

# %%
import os

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.11/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.11/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import pandas as pd
from io import StringIO
import seaborn as sns 
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %%
tput = tx_node.execute("cd " + data_dir + "; grep 'Kbits/sec.*receiver' *.txt | awk -F'[_ .]' '{print $1\",\"$2\",\"$3\",\"$4\",\"$5\",\"$21}' ", quiet=True)

# %%
df_tput = pd.read_csv(StringIO(tput[0]), names = ['bufcap','bandwidth','rtt','trial','cc','goodput_'])
# force it to drop bad runs
df_tput['goodput_'] = pd.to_numeric(df_tput['goodput_'], errors='coerce').dropna()
df_tput.to_csv('data/tput_tbf.csv')
df_tput = df_tput.pivot_table(columns='cc', index=['bufcap','bandwidth','rtt'], values=['goodput_'], aggfunc='mean').reset_index() 
df_tput.columns = [''.join(col).strip() for col in df_tput.columns.values]
df_tput = df_tput.assign(goodput_gain = 100*(df_tput['goodput_' + exp_factors['cc'][1]]-df_tput['goodput_' + exp_factors['cc'][0]])/df_tput['goodput_' + exp_factors['cc'][0]])

# %%
dat_hm = df_tput[df_tput.bufcap==100].pivot(index=["bandwidth"], columns=["rtt"], values="goodput_gain")
sns.set(font_scale=0.8)
ax = sns.heatmap(dat_hm, annot=True, fmt=".1f", cmap="RdBu_r", center=0, vmin=-100, vmax=100)
ax.invert_yaxis()
ax.set_title("Goodput gain for " + exp_factors['cc'][1].upper() + " vs " + exp_factors['cc'][0].upper() + ", 100KB buffer, " + kernel + " kernel")
plt.xlabel("RTT (in ms)")
plt.ylabel("Bandwidth (in Mbps)")
plt.show()

# %%
dat_hm = df_tput[df_tput.bufcap==10000].pivot(index=["bandwidth"], columns=["rtt"], values="goodput_gain")
sns.set(font_scale=0.8)
ax = sns.heatmap(dat_hm, annot=True, fmt=".1f", cmap="RdBu_r", center=0, vmin=-100, vmax=100)
ax.invert_yaxis()
ax.set_title("Goodput gain for " + exp_factors['cc'][1].upper() + " vs " + exp_factors['cc'][0].upper() + ", 10MB buffer, " + kernel + " kernel")
plt.xlabel("RTT (in ms)")
plt.ylabel("Bandwidth (in Mbps)")
plt.show()

# %%
df_tput = pd.read_csv(StringIO(tput[0]), names = ['bufcap','bandwidth','rtt','trial','cc','goodput_'])
df_tput['goodput_'] = pd.to_numeric(df_tput['goodput_'], errors='coerce').dropna()
df_tput = df_tput.pivot_table(columns='cc', index=['bufcap','bandwidth','rtt'], values=['goodput_'], aggfunc='mean').reset_index() 
df_tput.columns = [''.join(col).strip() for col in df_tput.columns.values]
df_tput = df_tput.assign(util = 100*(df_tput['goodput_' + exp_factors['cc'][0] ]/(df_tput['bandwidth']*1000)))
dat_hm = df_tput[df_tput.bufcap==100].pivot(index=["bandwidth"], columns=["rtt"], values="util")
sns.set(font_scale=0.8)
ax = sns.heatmap(dat_hm, annot=True, fmt=".0f", cmap="RdBu_r", center=50, vmin=0, vmax=100)
ax.invert_yaxis()
ax.set_title("Utilization for " + exp_factors['cc'][0].upper() + ", 100KB buffer, " + kernel + " kernel")
plt.xlabel("RTT (in ms)")
plt.ylabel("Bandwidth (in Mbps)")
plt.show()

# %%
df_tput = pd.read_csv(StringIO(tput[0]), names = ['bufcap','bandwidth','rtt','trial','cc','goodput_'])
df_tput['goodput_'] = pd.to_numeric(df_tput['goodput_'], errors='coerce').dropna()
df_tput = df_tput.pivot_table(columns='cc', index=['bufcap','bandwidth','rtt'], values=['goodput_'], aggfunc='mean').reset_index() 
df_tput.columns = [''.join(col).strip() for col in df_tput.columns.values]
df_tput = df_tput.assign(util = 100*(df_tput['goodput_' + exp_factors['cc'][0] ]/(df_tput['bandwidth']*1000)))
dat_hm = df_tput[df_tput.bufcap==10000].pivot(index=["bandwidth"], columns=["rtt"], values="util")
sns.set(font_scale=0.8)
ax = sns.heatmap(dat_hm, annot=True, fmt=".0f", cmap="RdBu_r", center=50, vmin=0, vmax=100)
ax.invert_yaxis()
ax.set_title("Utilization for " + exp_factors['cc'][0].upper() + ", 10MB buffer, " + kernel + " kernel")
plt.xlabel("RTT (in ms)")
plt.ylabel("Bandwidth (in Mbps)")
plt.show()

# %%
df_tput = pd.read_csv(StringIO(tput[0]), names = ['bufcap','bandwidth','rtt','trial','cc','goodput_'])
df_tput['goodput_'] = pd.to_numeric(df_tput['goodput_'], errors='coerce').dropna()
df_tput = df_tput.pivot_table(columns='cc', index=['bufcap','bandwidth','rtt'], values=['goodput_'], aggfunc='mean').reset_index() 
df_tput.columns = [''.join(col).strip() for col in df_tput.columns.values]
df_tput = df_tput.assign(util = 100*(df_tput['goodput_' + exp_factors['cc'][1] ]/(df_tput['bandwidth']*1000)))
dat_hm = df_tput[df_tput.bufcap==100].pivot(index=["bandwidth"], columns=["rtt"], values="util")
sns.set(font_scale=0.8)
ax = sns.heatmap(dat_hm, annot=True, fmt=".0f", cmap="RdBu_r", center=50, vmin=0, vmax=100)
ax.invert_yaxis()
ax.set_title("Utilization for " + exp_factors['cc'][1].upper() + ", 100KB buffer, " + kernel + " kernel")
plt.xlabel("RTT (in ms)")
plt.ylabel("Bandwidth (in Mbps)")
plt.show()

# %%
df_tput = pd.read_csv(StringIO(tput[0]), names = ['bufcap','bandwidth','rtt','trial','cc','goodput_'])
df_tput['goodput_'] = pd.to_numeric(df_tput['goodput_'], errors='coerce').dropna()
df_tput = df_tput.pivot_table(columns='cc', index=['bufcap','bandwidth','rtt'], values=['goodput_'], aggfunc='mean').reset_index() 
df_tput.columns = [''.join(col).strip() for col in df_tput.columns.values]
df_tput = df_tput.assign(util = 100*(df_tput['goodput_' + exp_factors['cc'][1] ]/(df_tput['bandwidth']*1000)))
dat_hm = df_tput[df_tput.bufcap==10000].pivot(index=["bandwidth"], columns=["rtt"], values="util")
sns.set(font_scale=0.8)
ax = sns.heatmap(dat_hm, annot=True, fmt=".0f", cmap="RdBu_r", center=50, vmin=0, vmax=100)
ax.invert_yaxis()
ax.set_title("Utilization for " + exp_factors['cc'][1].upper() + ", 10MB buffer, " + kernel + " kernel")
plt.xlabel("RTT (in ms)")
plt.ylabel("Bandwidth (in Mbps)")
plt.show()

# %%
retx = tx_node.execute("cd " + data_dir + "; grep 'Kbits/sec.*sender' *.txt | awk -F'[_ .]' '{print $1\",\"$2\",\"$3\",\"$4\",\"$5\",\"$24}' ", quiet=True)

# %%
df_retx = pd.read_csv(StringIO(retx[0]), names = ['bufcap','bandwidth','rtt','trial','cc','retx_'])
df_retx = df_retx.fillna(0).drop(columns=['trial'])
df_retx.to_csv('data/retx_tbf.csv')
df_retx['retx_'] = df_retx.loc[:,'retx_'].astype(float)/1000
df_retx.head()
df_retx = df_retx.pivot_table(columns='cc', index=['bufcap','bandwidth','rtt'], values=['retx_'], aggfunc='mean').reset_index() 
df_retx.columns = [''.join(col).strip() for col in df_retx.columns.values]

# %%
dat_hm_1 = df_retx[df_retx.bufcap==100].pivot(index=["bandwidth"], columns=["rtt"], values="retx_"+exp_factors['cc'][0] )
dat_hm_2 = df_retx[df_retx.bufcap==100].pivot(index=["bandwidth"], columns=["rtt"], values="retx_"+exp_factors['cc'][1] )

vmin = min(dat_hm_1.min().min(), dat_hm_2.min().min())
vmax = max(dat_hm_1.max().max(), dat_hm_2.max().max())

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

sns.set(font_scale=0.8)
sns.heatmap(dat_hm_1, ax=axes[0], annot=True, fmt=".1f", norm=LogNorm(vmin=vmin, vmax=vmax), cmap="plasma", cbar=True)
axes[0].invert_yaxis()
axes[0].set_title("Retransmissions for " + exp_factors['cc'][0].upper() + ", 100kB buffer, " + kernel + " kernel")
axes[0].set_xlabel("delay (in ms)")
axes[0].set_xlabel("Bandwidth (in Mbps)")

sns.set(font_scale=0.8)
sns.heatmap(dat_hm_2, ax=axes[1], annot=True, fmt=".0f", norm=LogNorm(vmin=vmin, vmax=vmax), cmap="plasma", cbar=True)
axes[1].invert_yaxis()
axes[1].set_title("Retransmissions for " + exp_factors['cc'][1].upper() + ", 100kB buffer, " + kernel + " kernel")
axes[1].set_xlabel("delay (in ms)")
axes[1].set_xlabel("Bandwidth (in Mbps)")

plt.show()
plt.tight_layout()
plt.show()
figure = axes[0].get_figure()
figure.savefig('Ret_100kB_Cubic.png')
figure = axes[1].get_figure()
figure.savefig('Ret_100kB_Bbr.png')

# %%
dat_hm = df_retx[df_retx.bufcap==100].pivot(index=["bandwidth"], columns=["rtt"], values="retx_"+exp_factors['cc'][0] )
sns.set(font_scale=0.8)
ax = sns.heatmap(dat_hm, annot=True, fmt=".0f", cmap="plasma_r",norm=LogNorm(), center=0)
ax.invert_yaxis()
ax.set_title("Retransmissions for " + exp_factors['cc'][0].upper() + ", 100kB buffer, " + kernel + " kernel")
plt.xlabel("RTT (in ms)")
plt.ylabel("Bandwidth (in Mbps)")
plt.show()

# %%
dat_hm = df_retx[df_retx.bufcap==100].pivot(index=["bandwidth"], columns=["rtt"], values="retx_"+exp_factors['cc'][1] )
sns.set(font_scale=0.8)
ax = sns.heatmap(dat_hm, annot=True, fmt=".0f", cmap="plasma_r",norm=LogNorm(), center=0)
ax.invert_yaxis()
ax.set_title("Retransmissions for " + exp_factors['cc'][1].upper() + ", 100kB buffer, " + kernel + " kernel")
plt.xlabel("RTT (in ms)")
plt.ylabel("Bandwidth (in Mbps)")
plt.show()

# %% [markdown]
# 100kB, 750Mbps, 10ms

# %%
import os
slice.get_node("h1").download_file(os.path.join(os.getcwd() + "/sender-ss_1.csv"), "sender-ss.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("sender-ss_1.csv", names=['time', 'sender', 'retx_unacked', 'retx_cum', 'cwnd', 'ssthresh', 'rtt'])
df.head()
# Out:
#            time           sender  retx_unacked  retx_cum  cwnd  ssthresh  \
# 0  1.720409e+09  10.10.1.1:42442           NaN       NaN    10        37
# 1  1.720409e+09  10.10.1.1:42442           NaN       NaN    10        41
# 2  1.720409e+09  10.10.1.1:42442           NaN       NaN    10        41
# 3  1.720409e+09  10.10.1.1:42442           NaN       NaN    10        41
# 4  1.720409e+09  10.10.1.1:42454           NaN       NaN    10        37
#
#       rtt
# 0  10.339
# 1  10.315
# 2  10.315
# 3  10.315
# 4  10.180

# %%
# Read data
df = pd.read_csv("sender-ss_1.csv", names=['time', 'sender', 'retx_unacked', 'retx_cum', 'cwnd', 'ssthresh', 'rtt'])
df['time'] = pd.to_numeric(df['time'], errors='coerce')
# df = df.dropna()
# Exclude "control" flow and keep senders with more than 100 data points
df_filtered = df[df.groupby("sender")['sender'].transform('size') > 100]

# Assuming the sender of interest is the one with the most data points
sender_of_interest = df_filtered['sender'].value_counts().idxmax()

# Filter data for the selected sender
df_single_sender = df_filtered[df_filtered['sender'] == sender_of_interest]

# Prepare plot data
time_min = df_single_sender['time'].min()
cwnd_max = 1.1 * df_single_sender['cwnd'].max()
# df_single_sender[df_single_sender['time'] == "1719781696.2039701719781696.203930"]

# Create a single plot for the sender of interest
plt.figure(figsize=(12, 6))
plt.plot(df_single_sender['time'] - time_min, df_single_sender['cwnd'], label="cwnd")
plt.plot(df_single_sender['time'] - time_min, df_single_sender['ssthresh'], label="ssthresh")
plt.ylim([0, cwnd_max])
plt.xlabel("Time (s)")
plt.ylabel("CWND / SSTHRESH")
plt.title(f"CWND and SSTHRESH over Time for Sender {sender_of_interest}")
plt.legend()

# Add grid to the plot
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.tight_layout()

# Save the figure
plt.savefig("sender-ss.png")
plt.show()

# %%
import os
slice.get_node("tbf").download_file(os.path.join(os.getcwd() + "/backlog_log_1.txt"), "backlog_log.txt")
slice.get_node("tbf").download_file(os.path.join(os.getcwd() + "/dropped_1.txt"), "Dropped.txt")

# %%
df_qSize = pd.read_csv('backlog_log_1.txt', sep=r'\s+', header=None, names=['time', 'queue_size_bytes', 'queue_size_packets']).reset_index()
df_qSize.drop(columns=['index'],inplace=True)
df_qSize['queue_size_bytes'] = df_qSize.loc[:,'queue_size_bytes'].str.replace('b','').str.replace('K','000').astype(int)
df_qSize['queue_size_packets'] = df_qSize.loc[:,'queue_size_packets'].str.replace('p','').astype(int)
df_qSize['time'] = pd.to_numeric(df['time'], errors='coerce')
# time_min = df_qSize['time'].min()
df_qSize = df_qSize[df_qSize['time']>=time_min]
df_qSize = df_qSize[df_qSize['time']<= df_single_sender['time'].max()]
df_qSize['time'] = df_qSize.loc[:,'time'].apply(lambda x: (x - time_min))
df_qSize.set_index('time', inplace=True)

df_qSize.drop(columns=['queue_size_packets'], inplace=True)
# threshold = 10000  # Define your threshold
# window_size = 5  # Number of entries in the window
# df_qSize = df_qSize['queue_size_bytes'].rolling(window=window_size).mean().dropna()# df_qSize = df_qSize[df_qSize['queue_size_bytes']>=40000]
# df_qSize.scatter()
plt.figure(figsize=(10, 6))
plt.plot(df_qSize.index, df_qSize['queue_size_bytes'])
plt.xlabel('Time (seconds)')
plt.ylabel('Queue Size')
plt.title('Queue Size Over Time')
plt.savefig('qsizeOverTime.png')
plt.show()

# %%
df_qDrop = pd.read_csv('dropped_1.txt', sep=r'\s+', header=None, names=['time', 'dropped']).reset_index()
df_qDrop.drop(columns=['index'], inplace=True)
df_qSize['time'] = pd.to_numeric(df['time'], errors='coerce')

df_qDrop = df_qDrop[df_qDrop['time'] >= time_min]
df_qDrop['time'] = df_qDrop['time'].apply(lambda x: (x - time_min))  # Convert to seconds
df_qDrop.set_index('time', inplace=True)
df_qDrop['dropped'] = df_qDrop['dropped'].str.replace(',', '').astype(int)
# df_qDrop['drop_change'] = df_qDrop['dropped'].diff().fillna(0).astype(bool)
# filtered = df_qDrop[df_qDrop['drop_change']]

# plt.figure(figsize=(10, 6))
# Plot vertical lines at the points where there is a drop change
# for time in filtered.index:
#     plt.axvline(x=time, color='red', linestyle='--', label='Packet Drop')
plt.figure(figsize=(10, 6))
plt.plot(df_qDrop.index, df_qDrop['dropped'])
# df_qDrop.plot()
plt.xlabel('Time (seconds)')
plt.ylabel('Packet Drop')
plt.title('Dropped Packets Over Time')
# plt.legend()
plt.savefig('packet_drop.png')
plt.show();

# %%
df_qDrop.tail(1)
# Out:
#            dropped
# time
# 62.596782      466

# %%
df_single_sender['ssthresh_change'] = df_single_sender['ssthresh'].diff().fillna(0).astype(bool)
ssthresh_change_times = df_single_sender[df_single_sender['ssthresh_change']]['time']

def get_data_around_time(time, df, window_size=5):
    start_time = time - window_size*(10**(-3))
    end_time = time + window_size*(10**(-3))
    return df[(df['time'] >= start_time) & (df['time'] <= end_time)]

# Collect all windows of data points around each ssthresh change time
windows = []
for change_time in ssthresh_change_times:
    window = get_data_around_time(change_time-time_min, df_qSize.reset_index(), window_size=5)
    windows.append(window)

# Combine all windows into a single DataFrame
result_df = pd.concat(windows)

# Display the result
print(result_df)
# Out:
#            time  queue_size_packets
# 0      0.000000                   0
# 1      0.017818                   0
# 2      0.035468                   0
# 3      0.054286                   0
# 0      0.000000                   0
# ...         ...                 ...
# 3281  59.630707                   0
# 3282  59.649981                   0
# 3283  59.667955                   0
# 3284  59.687391                   7
# 3285  59.705570                   0
#
# [274 rows x 2 columns]

# %% [markdown]
# 100kB, 100Mbps, 10ms

# %%
import os
slice.get_node("h1").download_file(os.path.join(os.getcwd() + "/sender-ss_2.csv"), "sender-ss.csv")

# %%
df = pd.read_csv("sender-ss_2.csv", names=['time', 'sender', 'retx_unacked', 'retx_cum', 'cwnd', 'ssthresh', 'rtt'])
df.head()
# Out:
#            time           sender  retx_unacked  retx_cum  cwnd  ssthresh  \
# 0  1.720413e+09  10.10.1.1:45374           NaN       NaN    10        37
# 1  1.720413e+09  10.10.1.1:45374           NaN       NaN    10        41
# 2  1.720413e+09  10.10.1.1:45374           NaN       NaN    10        41
# 3  1.720413e+09  10.10.1.1:45374           NaN       NaN    10        41
# 4  1.720413e+09  10.10.1.1:45374           NaN       NaN    10       181
#
#       rtt
# 0  10.256
# 1  10.244
# 2  10.244
# 3  10.244
# 4  15.536

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data
df = pd.read_csv("sender-ss_2.csv", names=['time', 'sender', 'retx_unacked', 'retx_cum', 'cwnd', 'ssthresh', 'rtt'])
df['time'] = pd.to_numeric(df['time'], errors='coerce')
# df = df.dropna()
# Exclude "control" flow and keep senders with more than 100 data points
df_filtered = df[df.groupby("sender")['sender'].transform('size') > 100]

# Assuming the sender of interest is the one with the most data points
sender_of_interest = df_filtered['sender'].value_counts().idxmax()

# Filter data for the selected sender
df_single_sender = df_filtered[df_filtered['sender'] == sender_of_interest]

# Prepare plot data
time_min = df_single_sender['time'].min()
cwnd_max = df_single_sender['cwnd'].max()

# df_single_sender[df_single_sender['time'] == "1719781696.2039701719781696.203930"]

# Create a single plot for the sender of interest
plt.figure(figsize=(12, 6))
plt.plot(df_single_sender['time'] - time_min, df_single_sender['cwnd'], label="cwnd")
plt.plot(df_single_sender['time'] - time_min, df_single_sender['ssthresh'], label="ssthresh")
plt.ylim([0, cwnd_max])
plt.xlabel("Time (s)")
plt.ylabel("CWND / SSTHRESH")
plt.title(f"CWND and SSTHRESH over Time for Sender {sender_of_interest}")
plt.legend()

# Add grid to the plot
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.tight_layout()

# Save the figure
plt.savefig("sender-ss.png")
plt.show()

# %%
import os
slice.get_node("tbf").download_file(os.path.join(os.getcwd() + "/backlog_log_2.txt"), "backlog_log.txt")
slice.get_node("tbf").download_file(os.path.join(os.getcwd() + "/dropped_2.txt"), "Dropped.txt")

# %%
df_qSize = pd.read_csv('backlog_log_2.txt', sep=r'\s+', header=None, names=['time', 'queue_size_bytes', 'queue_size_packets']).reset_index()
df_qSize.drop(columns=['index'],inplace=True)
df_qSize['queue_size_bytes'] = df_qSize.loc[:,'queue_size_bytes'].str.replace('b','').str.replace('K','000').astype(int)
df_qSize['queue_size_packets'] = df_qSize.loc[:,'queue_size_packets'].str.replace('p','').astype(int)
df_qSize['time'] = pd.to_numeric(df['time'], errors='coerce')
# time_min = df_qSize['time'].min()
df_qSize = df_qSize[df_qSize['time']>=time_min]
df_qSize = df_qSize[df_qSize['time']<= df_single_sender['time'].max()]
df_qSize['time'] = df_qSize.loc[:,'time'].apply(lambda x: (x - time_min))
df_qSize.set_index('time', inplace=True)

df_qSize.drop(columns=['queue_size_packets'], inplace=True)
# threshold = 10000  # Define your threshold
# window_size = 5  # Number of entries in the window
# df_qSize = df_qSize['queue_size_bytes'].rolling(window=window_size).mean().dropna()# df_qSize = df_qSize[df_qSize['queue_size_bytes']>=40000]
# df_qSize.scatter()
plt.figure(figsize=(10, 6))
plt.plot(df_qSize.index, df_qSize['queue_size_bytes'])
plt.xlabel('Time (seconds)')
plt.ylabel('Queue Size')
plt.title('Queue Size Over Time')
plt.savefig('qsizeOverTime.png')
plt.show()

# %%
df_qDrop = pd.read_csv('dropped_2.txt', sep=r'\s+', header=None, names=['time', 'dropped']).reset_index()
df_qDrop.drop(columns=['index'], inplace=True)
df_qSize['time'] = pd.to_numeric(df['time'], errors='coerce')

df_qDrop = df_qDrop[df_qDrop['time'] >= time_min]
df_qDrop['time'] = df_qDrop['time'].apply(lambda x: (x - time_min))  # Convert to seconds
df_qDrop.set_index('time', inplace=True)
df_qDrop['dropped'] = df_qDrop['dropped'].str.replace(',', '').astype(int)
# df_qDrop['drop_change'] = df_qDrop['dropped'].diff().fillna(0).astype(bool)
# filtered = df_qDrop[df_qDrop['drop_change']]

# plt.figure(figsize=(10, 6))
# Plot vertical lines at the points where there is a drop change
# for time in filtered.index:
#     plt.axvline(x=time, color='red', linestyle='--', label='Packet Drop')
plt.figure(figsize=(10, 6))
plt.plot(df_qDrop.index, df_qDrop['dropped'])
# df_qDrop.plot()
plt.xlabel('Time (seconds)')
plt.ylabel('Packet Drop')
plt.title('Dropped Packets Over Time')
# plt.legend()
plt.savefig('packet_drop.png')
plt.show();

# %%
df_single_sender['ssthresh_change'] = df_single_sender['ssthresh'].diff().fillna(0).astype(bool)
ssthresh_change_times = df_single_sender[df_single_sender['ssthresh_change']]['time']
df_qSize = df_qSize.drop(columns=['time'])
def get_data_around_time(time, df, window_size=5):
    start_time = time - window_size*(10**(-3))
    end_time = time + window_size*(10**(-3))
    return df[(df['time'] >= start_time) & (df['time'] <= end_time)]

# Collect all windows of data points around each ssthresh change time
windows = []
for change_time in ssthresh_change_times:
    window = get_data_around_time(change_time-time_min, df_qSize.reset_index(), window_size=5)
    windows.append(window)

# Combine all windows into a single DataFrame
result_df = pd.concat(windows)

# Display the result
print(result_df)
# Out:
#            time  queue_size_bytes
# 1      0.017395                 0
# 2      0.038816                 0
# 3      0.056424                 0
# 4      0.079441                 0
# 68     1.255402                 0
# 125    2.295467                 0
# 212    3.896094                 0
# 235    4.351891                 0
# 335    6.213212             62074
# 409    7.632529             83270
# 557   10.402907             74186
# 713   13.231616             78728
# 929   17.196172             49962
# 952   17.604958             51476
# 1061  19.589471             96896
# 1739  31.907582             86298
# 1827  33.435661             49962
# 1880  34.370598             66616
# 1971  35.993141             86298
# 2121  38.769288             81756
# 2199  40.209227             43906
# 2278  41.587150             66616
# 2354  42.954871             96896
# 2435  44.413892             51476
# 2511  45.797906             77214
# 2590  47.222306             36336
# 2689  49.089877             27252
# 2794  50.944530             74186
# 3221  58.905475             86298

# %% [markdown]
# ### Transfer experiment data

# %%
tx_node.execute('tar -czf ' + data_dir + '.tgz ' + data_dir)

# %%
tx_node.download_file(data_dir + '.tgz', '/home/ubuntu/' + data_dir + '.tgz')

# %% [markdown]
# ### Delete your slice

# %% [markdown]
# When you finish your experiment, you should delete your slice! The following cells deletes all the resources in your slice, freeing them for other experimenters.

# %%
slice = fablib.get_slice(name=slice_name)
fablib.delete_slice(slice_name)

# %%
# slice should end up in "Dead" state
# re-run this cell until you see it in "Dead" state
slice.update()
_ = slice.show()
# Out:
# <style type="text/css">
# #T_ddb39 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ddb39 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ddb39 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_ddb39_row0_col0, #T_ddb39_row0_col1, #T_ddb39_row1_col0, #T_ddb39_row1_col1, #T_ddb39_row2_col0, #T_ddb39_row2_col1, #T_ddb39_row3_col0, #T_ddb39_row3_col1, #T_ddb39_row4_col0, #T_ddb39_row4_col1, #T_ddb39_row5_col0, #T_ddb39_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_ddb39">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ddb39_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_ddb39_row0_col1" class="data row0 col1" >6769290e-74c3-4095-8e17-90e12587ffb1</td>
#     </tr>
#     <tr>
#       <td id="T_ddb39_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_ddb39_row1_col1" class="data row1 col1" >re-when-to-use-bbr-nm3833_0000195331</td>
#     </tr>
#     <tr>
#       <td id="T_ddb39_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_ddb39_row2_col1" class="data row2 col1" >2024-07-10 18:28:19 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ddb39_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_ddb39_row3_col1" class="data row3 col1" >2024-07-03 18:21:32 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ddb39_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_ddb39_row4_col1" class="data row4 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_ddb39_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_ddb39_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
